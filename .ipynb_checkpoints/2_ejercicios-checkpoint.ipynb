# %% [markdown]
# # Analizando una Imagen

# %%
import matplotlib.pyplot as plt 
img = plt.imread('beagle.jpg')
img.shape

img[10,10]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 img = plt.imread('beagle.jpg')
#       3 img.shape
#       4
#       5 img[10,10]
#
# File ~/mi_proyecto_numpy/.venv/lib/python3.12/site-packages/matplotlib/pyplot.py:2763, in imread(fname, format)
#    2759 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2760 def imread(
#    2761         fname: str | pathlib.Path | BinaryIO, format: str | None = None
#    2762 ) -> np.ndarray:
# -> 2763     return matplotlib.image.imread(fname, format)
#
# File ~/mi_proyecto_numpy/.venv/lib/python3.12/site-packages/matplotlib/image.py:1587, in imread(fname, format)
#    1580 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1581     # Pillow doesn't handle URLs directly.
#    1582     raise ValueError(
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 39.4 MB/s eta 0:00:0000:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.6/362.6 kB 26.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 60.7 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 41.7 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 55.8 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.8/122.8 kB 13.4 MB/s eta 0:00:00
# ...
